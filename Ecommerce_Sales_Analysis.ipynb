# %% [markdown]
# Based on the analysis of the 100 orders:
#
# 1. **Overall sales:** The dataset generated total sales of **₹447,262.95**, with an average order value of approximately **₹4,472.63**.
# 2. **Order range:** The highest-value order was **Order ID 1049** at **₹13,995.00**, while the lowest-value order was **Order ID 1006** at **₹449.10**.
# 3. **Category leader:** **Sports** generated the highest total sales among all categories.
# 4. **City leader:** **Hyderabad** recorded the highest total sales among the listed cities.
# 5. **Product leader:** **Coffee Maker** was the top-performing product by total sales.
# 6. **Payment methods:** **Credit Card** generated the highest total sales overall, while **Net Banking** had the highest average order value.
# 7. **Quantity:** A total of **294 units** were sold across **100 orders**.
# 8. The analysis shows that **sales value, order frequency, and quantity sold do not always identify the same leader**, so all three measures are useful when evaluating product or category performance.

# %% [markdown]
# ## 14. Conclusion
#
# Pandas makes it possible to move from raw transactional data to useful business insights using a small set of core operations. In this notebook, `loc`/column selection, Boolean filtering, sorting, `groupby()`, and aggregation functions such as `sum()`, `mean()`, `max()`, `min()`, and `count()` were used to evaluate e-commerce performance across categories, cities, products, and payment methods.
#
# The results can help identify strong-performing products and categories, high-value markets, and customer payment preferences.
